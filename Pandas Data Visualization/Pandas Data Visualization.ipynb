# %% [markdown]
# ### Content
# - Libraries
# - Barplot (Simple, multiple, sub-divided)
# - Pie chart
# - Histogram
# - Density plot
# - Boxplot
# - Scatterplot

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('Attrition1.csv')
df.head()
# Out:
#    Age  Attrition     BusinessTravel  DailyRate              Department  \
# 0   41          1      Travel_Rarely       1102                   Sales
# 1   49          0  Travel_Frequently        279  Research & Development
# 2   37          1      Travel_Rarely       1373  Research & Development
# 3   33          0  Travel_Frequently       1392  Research & Development
# 4   27          0      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome EducationField  Gender  HourlyRate                JobRole  \
# 0                 1  Life Sciences  Female          94        Sales Executive
# 1                 8  Life Sciences    Male          61     Research Scientist
# 2                 2          Other    Male          92  Laboratory Technician
# 3                 3  Life Sciences  Female          56     Research Scientist
# 4                 2        Medical    Male          40  Laboratory Technician
#
# ...

# %% [markdown]
# ### The Pandas Plot Function
# Pandas has a built in .plot() function as part of the DataFrame class. It has several key parameters:
#
# * kind — ‘bar’,’barh’,’pie’,’scatter’,’kde’ etc.
# * color — Which accepts and array of hex codes corresponding sequential to each data series / column.
# * linestyle — ‘solid’, ‘dotted’, ‘dashed’ (applies to line graphs only)
# * xlim, ylim — specify a tuple (lower limit, upper limit) for which the plot will be drawn
# * legend— a boolean value to display or hide the legend
# * labels — a list corresponding to the number of columns in the dataframe, a descriptive name can be provided here for the legend
# * title — The string title of the plot

# %%
#Bar chart for business travel
# colors = ['yellowgreen', 'gold', 'lightskyblue', 'lightcoral','red','green','blue','orange','white','brown']
var = df['BusinessTravel'].value_counts()
print(var)
#var.plot(kind = 'bar', title = 'Bar plot for Business Travel')
var.plot.bar(title = 'Bar plot for Business Travel')
# Out:
# Travel_Rarely        1043
# Travel_Frequently     277
# Non-Travel            150
# Name: BusinessTravel, dtype: int64
# <AxesSubplot:title={'center':'Bar plot for Business Travel'}>

# %%
var = df['BusinessTravel'].value_counts()/df.shape[0]*100
print(var)
#var.plot(kind = 'bar', title = 'Bar plot for Business Travel')
var.plot.bar(title = 'Bar plot for Business Travel')
# Out:
# Travel_Rarely        70.952381
# Travel_Frequently    18.843537
# Non-Travel           10.204082
# Name: BusinessTravel, dtype: float64
# <AxesSubplot:title={'center':'Bar plot for Business Travel'}>

# %%
var=df['BusinessTravel'].value_counts()
print(var)
# Out:
# Travel_Rarely        1043
# Travel_Frequently     277
# Non-Travel            150
# Name: BusinessTravel, dtype: int64

# %%
var.index
# Out:
# Index(['Travel_Rarely', 'Travel_Frequently', 'Non-Travel'], dtype='object')

# %%
var.plot.bar(title = 'Bar plot',color = ['green','blue','red'])  #no need of color
# Out:
# <AxesSubplot:title={'center':'Bar plot'}>

# %%
var.plot.bar(title='Bar plot for Business Travel', ylim=[0,1400])
# Out:
# <AxesSubplot:title={'center':'Bar plot for Business Travel'}>

# %%
var.plot.bar(title='Bar plot', ylim=[0,1200],legend = True) #no need for legend
# Out:
# <AxesSubplot:title={'center':'Bar plot'}>

# %%
var.plot.barh(title = 'Bar plot')
# Out:
# <AxesSubplot:title={'center':'Bar plot'}>

# %%
t1 = pd.crosstab(df.BusinessTravel,df.Gender)#.T
print(t1)
t1.plot.bar(title = 'Multiple Bar plot',
            color=['red','blue'],
            ylim=[0,700],legend = True)
# Out:
# Gender             Female  Male
# BusinessTravel
# Non-Travel             49   101
# Travel_Frequently     117   160
# Travel_Rarely         422   621
# <AxesSubplot:title={'center':'Multiple Bar plot'}, xlabel='BusinessTravel'>

# %%
t1 = pd.crosstab(df.BusinessTravel,df.Gender).T
print(t1)
t1.plot.bar(title = 'Multiple Bar plot',
            color=['red','yellow','blue'],
            ylim=[0,700],legend = True)
# Out:
# BusinessTravel  Non-Travel  Travel_Frequently  Travel_Rarely
# Gender
# Female                  49                117            422
# Male                   101                160            621
# <AxesSubplot:title={'center':'Multiple Bar plot'}, xlabel='Gender'>

# %%
t1.plot.bar(stacked=True,title='Sub-divided Bar plot',color=['g','y']
        ,ylim=[0,1500],legend = True)
# Out:
# <AxesSubplot:title={'center':'Sub-divided Bar plot'}, xlabel='BusinessTravel'>

# %%
t1.T.plot.bar(stacked=True,title='Sub-divided bar plot',
             ylim=[0,1000])
# Out:
# <AxesSubplot:title={'center':'Sub-divided bar plot'}, xlabel='Gender'>

# %%
# Pie chart for Business travel
#var.plot(kind='pie',title='Pie chart')
var.plot.pie(title='Pie chart')
# Out:
# <AxesSubplot:title={'center':'Pie chart'}, ylabel='BusinessTravel'>

# %%
JR = df['JobRole'].value_counts()
print(JR)
JR.plot.pie(title='Pie chart',figsize=(6,6))
# Out:
# Sales Executive              326
# Research Scientist           292
# Laboratory Technician        259
# Manufacturing Director       145
# Healthcare Representative    131
# Manager                      102
# Sales Representative          83
# Research Director             80
# Human Resources               52
# Name: JobRole, dtype: int64
# <AxesSubplot:title={'center':'Pie chart'}, ylabel='JobRole'>

# %%
#Histogram for Age
df.Age.plot.hist(title='Histogram')
# Out:
# <AxesSubplot:title={'center':'Histogram'}, ylabel='Frequency'>

# %%
df.YearsAtCompany.plot.hist(title='Histogram',color='r')
# Out:
# <AxesSubplot:title={'center':'Histogram'}, ylabel='Frequency'>

# %%
#kde for age
df.Age.plot.kde(color='r',linestyle='solid')#'dashed'#,solid dotted)
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
#KDE for years @company
df.YearsAtCompany.plot.kde(title='Density',color='g',linestyle='solid')
# Out:
# <AxesSubplot:title={'center':'Density'}, ylabel='Density'>

# %%
df.Age.plot.box(title='Boxplot')
# Out:
# <AxesSubplot:title={'center':'Boxplot'}>

# %%
df.YearsAtCompany.plot.box(color='r',title='Boxplot')
# Out:
# <AxesSubplot:title={'center':'Boxplot'}>

# %%
# Scatterplot for Age and MonthlyIncome
df.plot.scatter(x='Age',y='MonthlyIncome',
    title='Scatter plot',colormap='viridis',figsize=(10,7))
# Out:
# <AxesSubplot:title={'center':'Scatter plot'}, xlabel='Age', ylabel='MonthlyIncome'>

# %%
# Scatterplot for Age and MonthlyIncome
df.plot.scatter(x='Age',y='YearsAtCompany',title='Scatter plot',figsize=(8,6))
# Out:
# <AxesSubplot:title={'center':'Scatter plot'}, xlabel='Age', ylabel='YearsAtCompany'>

# %%
df.plot.scatter(x='PercentSalaryHike',y='Age')
# Out:
# <AxesSubplot:xlabel='PercentSalaryHike', ylabel='Age'>
